# %%
# ==============================================================================
# CELDA 1: PIENZA COMMAND CENTER - BOOTSTRAP (SECURE VERSION)
# ==============================================================================
# Status: Hardened. Logic decoupled from credentials.
# ==============================================================================
from google.colab import drive, userdata # <--- Inyectamos el gestor de secretos
import os

# 1. Montar Bóveda de Google Drive
print("📂 Sincronizando con Google Drive...")
drive.mount('/content/drive')

# 2. Configuración de Credenciales SOBERANAS
GITHUB_USER = "WiseExMachina"

# Recuperamos la llave desde el búnker de 'Secrets' (Icono de llave 🔑 a la izquierda)
try:
    GITHUB_TOKEN = userdata.get('Git_Secret') # <--- Nombre de tu Secret
    print("✅ Llave Maestra (Secret) recuperada del búnker.")
except userdata.SecretNotFoundError:
    print("🔴 ERROR: No se encontró el Secret llamado 'Github'.")
    print("   Asegúrate de que el nombre sea exacto y que hayas dado permiso al notebook.")
    raise

REPO_NAME = "pienza"

# 3. DEFINICIÓN DE RUTA MAESTRA (GITHUB REPOSITORY)
REPO_PATH = f"/content/drive/MyDrive/_Pienza/Github_Repository/{REPO_NAME}"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# 4. Configuración de Identidad Git
# !git config --global user.email "bernardolw@gmail.com"
# !git config --global user.name "{GITHUB_USER}"

print(f"\n✅ INFRAESTRUCTURA LISTA Y SEGURA.")
print(f"📍 Coordenada del Repo: {REPO_PATH}")
# Out:
# 📂 Sincronizando con Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Llave Maestra (Secret) recuperada del búnker.
#
# ✅ INFRAESTRUCTURA LISTA Y SEGURA.
# 📍 Coordenada del Repo: /content/drive/MyDrive/_Pienza/Github_Repository/pienza

# %%
# ==============================================================================
# CELDA 2: CLONAR O SINCRONIZAR
# ==============================================================================
if not os.path.exists(REPO_PATH):
    print(f"🚀 No se detectó repo local. Clonando {REPO_NAME} en la Bóveda...")
    os.makedirs(os.path.dirname(REPO_PATH), exist_ok=True)
    # !git clone {REPO_URL} "{REPO_PATH}"
else:
    print(f"🔄 Repositorio detectado. Sincronizando (PULL) desde GitHub...")
    # %cd "{REPO_PATH}"
    # !git pull origin main

print("\n✅ ESTADO: SINCRONIZADO CON LA NUBE.")
# Out:
# 🔄 Repositorio detectado. Sincronizando (PULL) desde GitHub...
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# From https://github.com/WiseExMachina/pienza
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# ✅ ESTADO: SINCRONIZADO CON LA NUBE.

# %% [markdown]
# # La siguiente celda ya no!!!

# %%
# ==============================================================================
# CELDA 3: THE SOVEREIGN PUSH (EL SELLO)
# ==============================================================================
# %cd "{REPO_PATH}"

# REGLA DEL ARQUITECTO: Cambia este mensaje antes de darle Play
COMMIT_MESSAGE = "primer commit desde colab"

print("📡 Enviando inteligencia a GitHub...")
# !git add .
# !git commit -m "{COMMIT_MESSAGE}"
# !git push origin main

print("\n🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 📡 Enviando inteligencia a GitHub...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
#
# 🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.

# %%
# ==============================================================================
# CELDA 3: THE SOVEREIGN PUSH (EL SELLO)
# ==============================================================================
# %cd "{REPO_PATH}"

# REGLA DEL ARQUITECTO: Cambia este mensaje antes de darle Play
COMMIT_MESSAGE = "created empty folders within notebooks"

print("📡 Enviando inteligencia a GitHub...")
# !git add .
# !git commit -m "{COMMIT_MESSAGE}"
# !git push origin main

print("\n🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 📡 Enviando inteligencia a GitHub...
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date
#
# 🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.

# %%
# ==============================================================================
# CELDA 3: THE SOVEREIGN PUSH (EL SELLO)
# ==============================================================================
# %cd "{REPO_PATH}"

# REGLA DEL ARQUITECTO: Cambia este mensaje antes de darle Play
COMMIT_MESSAGE = "agregué libretas a EDA"

print("📡 Enviando inteligencia a GitHub...")
# !git add .
# !git commit -m "{COMMIT_MESSAGE}"
# !git push origin main

print("\n🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 📡 Enviando inteligencia a GitHub...
# [main 3906e6a] agregué libretas a EDA
#  8 files changed, 8 insertions(+)
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Convergencia_a_la_media.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Hidden_Subsidy_Test.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Protocolo_Alpha.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_bivariado_financials.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_bivariado_temporal.ipynb
#  create mode 100644 Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_univariado.ipynb
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (12/12), 21.04 MiB | 5.58 MiB/s, done.
# Total 12 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/WiseExMachina/pienza.git
#    8811e0e..3906e6a  main -> main
#
# 🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.

# %%
# ==============================================================================
# CELDA 3: THE SOVEREIGN PUSH (EL SELLO)
# ==============================================================================
# %cd "{REPO_PATH}"

# REGLA DEL ARQUITECTO: Cambia este mensaje antes de darle Play
COMMIT_MESSAGE = "primer commit de pienza papers scientific report"

print("📡 Enviando inteligencia a GitHub...")
# !git add .
# !git commit -m "{COMMIT_MESSAGE}"
# !git push origin main

print("\n🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 📡 Enviando inteligencia a GitHub...
# [main c5dcaff] primer commit de pienza papers scientific report
#  15 files changed, 1002 insertions(+)
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/00_introduction.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/01_acquisition.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/02_engineering.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/03_eda.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/04_clustering.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/05_supervised.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/06_gan_sim.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/98_glossary.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/99_appendix.tex
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/Pienza_ERD.png
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/fig_condesa_buffer.png
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/fig_condesa_linear.png
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/fig_sf_buffer.png
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/fig_sf_linear.png
#  create mode 100644 The_Pienza_Papers/Pienza_Papers_Scientific/main.tex
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (14/14), 2.78 MiB | 3.86 MiB/s, done.
# Total 14 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/WiseExMachina/pienza.git
#    3906e6a..c5dcaff  main -> main
#
# 🏆 PROGRESO PROTEGIDO. Puedes cerrar la sesión.

# %%
# ==============================================================================
# OPERACIÓN: CREAR RAMA DEVELOPMENT
# ==============================================================================
# %cd "{REPO_PATH}"

# Creamos la rama 'dev' localmente y nos cambiamos a ella
# !git checkout -b dev

# La subimos a GitHub por primera vez
# !git push -u origin dev

print("\n🚀 EJE 'DEV' ESTABLECIDO. Estás trabajando en el taller.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# Switched to a new branch 'dev'
# To https://github.com/WiseExMachina/pienza.git
#  ! [rejected]        dev -> dev (non-fast-forward)
# error: failed to push some refs to 'https://github.com/WiseExMachina/pienza.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
#
# 🚀 EJE 'DEV' ESTABLECIDO. Estás trabajando en el taller.

# %%
# ==============================================================================
# REPARACIÓN DE EJE: SINCRONIZAR RAMA DEV EXISTENTE
# ==============================================================================
import os
# %cd "{REPO_PATH}"

print("🔧 Iniciando protocolo de fusión de historias...")

# 1. Asegurar que estamos en la rama local dev
# !git checkout dev

# 2. Conectar la rama local con la remota
print("\n📡 Descargando historia de 'origin/dev'...")
# !git fetch origin

# 3. Fusionar (El Handshake)
# Esto tomará lo que está en GitHub y lo mezclará con lo que tienes en Drive
# !git branch --set-upstream-to=origin/dev dev
# !git pull origin dev --allow-unrelated-histories

print("\n✅ SINCRONIZACIÓN COMPLETADA.")
print("   Ahora tu 'dev' local y tu 'dev' remoto son uno mismo.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 🔧 Iniciando protocolo de fusión de historias...
# Already on 'dev'
#
# 📡 Descargando historia de 'origin/dev'...
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# From https://github.com/WiseExMachina/pienza
#  * branch            dev        -> FETCH_HEAD
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# hint: or --ff-only on the command line to override the configured default per
# hint: invocation.
# fatal: Need to specify how to reconcile divergent branches.
#
# ✅ SINCRONIZACIÓN COMPLETADA.
#    Ahora tu 'dev' local y tu 'dev' remoto son uno mismo.

# %%
# ==============================================================================
# REPARACIÓN DE EJE: FUSIÓN FORZOSA (MERGE STRATEGY)
# ==============================================================================
import os
# %cd "{REPO_PATH}"

print("🔧 Configurando estrategia de fusión...")

# 1. Definir la estrategia por defecto: MERGE (No rebase)
# !git config pull.rebase false

# 2. Ejecutar el Pull con permiso de historias no relacionadas
# --no-edit evita que se abra un editor de texto que trabaría Colab
print("📡 Ejecutando fusión de historias...")
# !git pull origin dev --allow-unrelated-histories --no-edit

print("\n✅ AHORA SÍ. Verifica arriba que no diga 'fatal'.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# 🔧 Configurando estrategia de fusión...
# 📡 Ejecutando fusión de historias...
# From https://github.com/WiseExMachina/pienza
#  * branch            dev        -> FETCH_HEAD
# Merge made by the 'ort' strategy.
#  notebooks/pienza_manifold/Opus_P4_GANV1_N1.ipynb   | 2917 ++++++
#  .../pienza_manifold/opus_P4_N0_Cloud_Foundry.ipynb |    0
#  .../pienza_mini/Opus_Phase_1_EDA_univariado.ipynb  | 9891 ++++++++++++++++++++
#  3 files changed, 12808 insertions(+)
#  create mode 100644 notebooks/pienza_manifold/Opus_P4_GANV1_N1.ipynb
#  rename opus_P4_N0_Cloud_Foundry.ipynb => notebooks/pienza_manifold/opus_P4_N0_Cloud_Foundry.ipynb (100%)
#  create mode 100644 notebooks/pienza_mini/Opus_Phase_1_EDA_univariado.ipynb
#
# ✅ AHORA SÍ. Verifica arriba que no diga 'fatal'.

# %% [markdown]
# # PASO 2: EL "DAILY PUSH" A DEV (Tu nueva Celda 3)
# Esta es la celda que usarás siempre. Nota que ahora el comando final es push origin dev.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Se creó libreta Pienza_Phase_6_GAN_denormalization.ipynb" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# Already on 'dev'
# Your branch is ahead of 'origin/dev' by 3 commits.
#   (use "git push" to publish your local commits)
# 🔍 Verificando estado del búnker...
# ?? Notebooks/Phase_6_GAN_Simulations/
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 49928c2] Se creó libreta Pienza_Phase_6_GAN_denormalization.ipynb
#  1 file changed, 1 insertion(+)
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 1.14 KiB | 61.00 KiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/WiseExMachina/pienza.git
#    340bf64..49928c2  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Actualizacion libreta Pienza_Phase_6_GAN_denormalization.ipynb,se desnormalizo dropoff y product_category" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev cbdb17c] Actualizacion libreta Pienza_Phase_6_GAN_denormalization.ipynb,se desnormalizo dropoff y product_category
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb (75%)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 48.22 KiB | 1.93 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/WiseExMachina/pienza.git
#    49928c2..cbdb17c  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Primer commit de libreta donde se entrena GAN_V3" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 8b0c03a] Primer commit de libreta donde se entrena GAN_V3
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training.ipynb
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 661.49 KiB | 6.48 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    cbdb17c..8b0c03a  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Cambio de GAN_V3 a V7; se reentrenó para limpiar catastrofe de pickups con PiPolygon" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# D	Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  D Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training_V7.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 3f30c0f] Cambio de GAN_V3 a V7; se reentrenó para limpiar catastrofe de pickups con PiPolygon
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training_V7.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 882.24 KiB | 6.63 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/WiseExMachina/pienza.git
#    8b0c03a..3f30c0f  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Primer commit masivo de libretas; pendiente refactorizacion masiva" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
# ?? Notebooks/Phase_2_Data_Engineering/
# ?? Notebooks/Phase_4_Unsupervised_ML/
# ?? Notebooks/Phase_5_Supervised_ML/
# ?? "Notebooks/Phase_6_GAN_Simulations/ Opus_P4_GAN_N3_V3.ipynb"
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_GANV1_N1.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N2_V2.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N3_V3(deprecada).ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_Network_NX_V1.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_Transformer_T2Z.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Opus_P4_opusdb_to_BQ.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/Pienza_GAN_2_BigQuery.ipynb
# ?? Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 83a3673] Primer commit masivo de libretas; pendiente refactorizacion masiva
#  61 files changed, 780 insertions(+)
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/ colab_final_disposition.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/ colab_session_context_generator.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Chrono Forge Pre Processing.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/DS25_M4_Reto_BernardoLozanoWise (Intento 2).ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/DS_C6_SC2_BernardoLozanoWise.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus Project: Trajectory Interpolation Engine v8.1 (Colab Edition)d1.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_ETL_Orchestrator_deprecated.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_ETL_v2.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_0_ETL_v3.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_0_ETL_v4.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_0_ETL_v5.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_0_ETL_v6.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_0_ETL_v7.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_1_Geospatial_Reconciliation_Part_1.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Opus_Phase_1_Geospatial_Reconciliation_Part_2.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/Tema_4_LG_6_2.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_asset_disposition.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_interpolation_prep.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_keystone_generator_v6.2_definitive.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_ledger_join_vFinal.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_log_enrichment.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/colab_vektor_engine_v5.0_ground_truth_session.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/etl_01_raw_ocr_loader.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/opus_1_phase_1_home_vector_alignment_score.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/opus_phase_1_feature_engineering_georeconciliation.ipynb
#  create mode 100644 Notebooks/Phase_2_Data_Engineering/opus_phase_1_geospatial_reconciliation_part_3_production.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Copy of Opus_Phase_2_ML_Clustering_GeoEspacial_Polygons.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_Feature_Engineering_Final_Polish.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN_V2.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_Polygons_deprecated.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_PCA.ipynb
#  create mode 100644 Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_Raw_Variables.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Copy of opus_1_phase_3_home_vector_alignment_score_v2.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N10_Arbol_multiclase.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N12_XGB_multiclase(deprecar).ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N13_XGB_multiclase.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N14_LogReg_multiclase_srtratk.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw(deprecar).ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N16_XGB_multiclase_FINAL.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N17_XGB_multiclase_cascada.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N1_PCA_V2_sin_meter_mano.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N2_PCA_V2_metiendo_mano.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N3_PCA_V2_metiendo_mano_con_KM.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N4_Bayesiano_Ingenuo.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N5_NB_numcat_multiclase.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N6_NB_numcat_binario.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N7_LogReg_multiclase.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N9_DCC_multiclase_deprecar.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/ Opus_P4_GAN_N3_V3.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_GANV1_N1.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N2_V2.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N3_V3(deprecada).ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_Network_NX_V1.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_Transformer_T2Z.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Opus_P4_opusdb_to_BQ.ipynb
#  create mode 100644 Notebooks/Phase_6_GAN_Simulations/Pienza_GAN_2_BigQuery.ipynb
#  create mode 100644 Notebooks/Pienza_Git_Control.ipynb
# Enumerating objects: 71, done.
# Counting objects: 100% (71/71), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (68/68), done.
# Writing objects: 100% (68/68), 29.29 MiB | 5.67 MiB/s, done.
# Total 68 (delta 13), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (13/13), completed with 1 local object.
# To https://github.com/WiseExMachina/pienza.git
#    3f30c0f..83a3673  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Actulizacion de nombre de libretas de Fase 6; pendiente: merge versiones antiguas en una sola libreta, version controlled" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# D	Notebooks/Phase_2_Data_Engineering/DS25_M4_Reto_BernardoLozanoWise (Intento 2).ipynb
# D	Notebooks/Phase_2_Data_Engineering/DS_C6_SC2_BernardoLozanoWise.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/ Opus_P4_GAN_N3_V3.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_GANV1_N1.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N2_V2.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N3_V3(deprecada).ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_Network_NX_V1.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_Transformer_T2Z.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Opus_P4_opusdb_to_BQ.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Pienza_GAN_2_BigQuery.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training_V7.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  D "Notebooks/Phase_2_Data_Engineering/DS25_M4_Reto_BernardoLozanoWise (Intento 2).ipynb"
#  D Notebooks/Phase_2_Data_Engineering/DS_C6_SC2_BernardoLozanoWise.ipynb
#  D "Notebooks/Phase_6_GAN_Simulations/ Opus_P4_GAN_N3_V3.ipynb"
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_GANV1_N1.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N2_V2.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_GAN_N3_V3(deprecada).ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_Network_NX_V1.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_Transformer_T2Z.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Opus_P4_opusdb_to_BQ.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Pienza_GAN_2_BigQuery.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Pienza_P6_GAN_Training_V7.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/Pienza_Phase_6_GAN_denormalization.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/01_Pienza_Phase_6_Network_NX_V1.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/02_Pienza_Phase_6_GAN_Training_N1.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/03_Pienza_Phase_6_GAN_Training_N2.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/04_Pienza_Phase_6_GAN_Training_N3_deprecar.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/05_Pienza_Phase_6_GAN_Training_N4.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/06_Pienza_Phase_6_GAN_Training_N5_V7.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/07_Pienza_Phase_6_ETL_opusdb_to_BigQuery.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/08_Pienza_Phase_6_ETL_GAN_to_BigQuery.ipynb
# ?? Notebooks/Phase_6_GAN_Simulations/09_Pienza_Phase_6_GAN_denormalization.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev d28e919] Actulizacion de nombre de libretas de Fase 6; pendiente: merge versiones antiguas en una sola libreta, version controlled
#  13 files changed, 1 insertion(+), 3 deletions(-)
#  delete mode 100644 Notebooks/Phase_2_Data_Engineering/DS25_M4_Reto_BernardoLozanoWise (Intento 2).ipynb
#  delete mode 100644 Notebooks/Phase_2_Data_Engineering/DS_C6_SC2_BernardoLozanoWise.ipynb
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_Transformer_T2Z.ipynb => 00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_Network_NX_V1.ipynb => 01_Pienza_Phase_6_Network_NX_V1.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_GANV1_N1.ipynb => 02_Pienza_Phase_6_GAN_Training_N1.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_GAN_N2_V2.ipynb => 03_Pienza_Phase_6_GAN_Training_N2.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_GAN_N3_V3(deprecada).ipynb => 04_Pienza_Phase_6_GAN_Training_N3_deprecar.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{ Opus_P4_GAN_N3_V3.ipynb => 05_Pienza_Phase_6_GAN_Training_N4.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Pienza_P6_GAN_Training_V7.ipynb => 06_Pienza_Phase_6_GAN_Training_N5_V7.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Opus_P4_opusdb_to_BQ.ipynb => 07_Pienza_Phase_6_ETL_opusdb_to_BigQuery.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Pienza_GAN_2_BigQuery.ipynb => 08_Pienza_Phase_6_ETL_GAN_to_BigQuery.ipynb} (100%)
#  rename Notebooks/Phase_6_GAN_Simulations/{Pienza_Phase_6_GAN_denormalization.ipynb => 09_Pienza_Phase_6_GAN_denormalization.ipynb} (100%)
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 2.08 KiB | 111.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    83a3673..d28e919  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Se migró el GAN entrenado V7 a Bigquery y se desnormalizo pickup, dropoff y categoría, manifold enriched" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_6_GAN_Simulations/06_Pienza_Phase_6_GAN_Training_N5_V7.ipynb
# M	Notebooks/Phase_6_GAN_Simulations/08_Pienza_Phase_6_ETL_GAN_to_BigQuery.ipynb
# M	Notebooks/Phase_6_GAN_Simulations/09_Pienza_Phase_6_GAN_denormalization.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_6_GAN_Simulations/06_Pienza_Phase_6_GAN_Training_N5_V7.ipynb
#  M Notebooks/Phase_6_GAN_Simulations/08_Pienza_Phase_6_ETL_GAN_to_BigQuery.ipynb
#  M Notebooks/Phase_6_GAN_Simulations/09_Pienza_Phase_6_GAN_denormalization.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev e4db07e] Se migró el GAN entrenado V7 a Bigquery y se desnormalizo pickup, dropoff y categoría, manifold enriched
#  4 files changed, 4 insertions(+), 4 deletions(-)
#  rewrite Notebooks/Phase_6_GAN_Simulations/08_Pienza_Phase_6_ETL_GAN_to_BigQuery.ipynb (90%)
#  rewrite Notebooks/Phase_6_GAN_Simulations/09_Pienza_Phase_6_GAN_denormalization.ipynb (97%)
#  rewrite Notebooks/Pienza_Git_Control.ipynb (91%)
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 171.47 KiB | 975.00 KiB/s, done.
# Total 8 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    d28e919..e4db07e  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
'''/content/drive/MyDrive/_Pienza/Forked_Files/Opus_Phase_1_EDA_Interacciones_Parada_Optima_vPaper.ipynb
RUTA_INCUBADORA = "/content/drive/MyDrive/_Pienza/Forked_Files/Opus_Phase_1_EDA_Interacciones_Parada_Optima_vPaper.ipynb"  # Donde trabajaste la nueva versión
RUTA_REPO_FINAL = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza/Notebooks/Phase_3_EDA" # Donde vive la original
/content/drive/MyDrive/_Pienza/Github_Repository/pienza/Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb'''

# %%
import shutil
import os

# ==============================================================================
# OPERACIÓN: TRASPLANTE DE CÓDIGO (MANTENIENDO HISTORIAL)
# ==============================================================================

# 1. CONFIGURACIÓN DE IDENTIDADES
# Nombre del archivo NUEVO (el que trabajaste afuera)
NOMBRE_ARCHIVO_ORIGEN = "Opus_Phase_1_EDA_Interacciones_Parada_Optima_vPaper.ipynb"  # <--- CAMBIA ESTO SI ES DIFERENTE

# Nombre del archivo VIEJO (el que está en el repo y quieres conservar)
NOMBRE_ARCHIVO_DESTINO = "Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb"

# 2. CONFIGURACIÓN DE RUTAS (CARPETAS)
# Carpeta donde está el nuevo
DIR_ORIGEN = "/content/drive/MyDrive/_Pienza/Forked_Files/"
# Carpeta donde está el viejo (Repo)
DIR_DESTINO = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza/Notebooks/Phase_3_EDA"

# 3. CONSTRUCCIÓN DE RUTAS COMPLETAS
ruta_origen_completa = os.path.join(DIR_ORIGEN, NOMBRE_ARCHIVO_ORIGEN)
ruta_destino_completa = os.path.join(DIR_DESTINO, NOMBRE_ARCHIVO_DESTINO)

# 4. EJECUCIÓN DEL TRASPLANTE
if os.path.exists(ruta_origen_completa):
    if os.path.exists(ruta_destino_completa):
        print(f"🔄 Iniciando trasplante...")
        print(f"   💊 Fuente (Nuevo): {NOMBRE_ARCHIVO_ORIGEN}")
        print(f"   💉 Destino (Repo): {NOMBRE_ARCHIVO_DESTINO}")

        # Esta función copia el contenido del origen y SOBREESCRIBE el destino
        # El archivo de destino mantendrá su nombre original, pero tendrá el contenido nuevo.
        shutil.copy2(ruta_origen_completa, ruta_destino_completa)

        print(f"\n✅ ÉXITO: El archivo en el repo '{NOMBRE_ARCHIVO_DESTINO}' ahora tiene el contenido de la V2.")
        print("   -> Git detectará esto como una 'Modificación' del archivo original.")
    else:
        print(f"🔴 ERROR: No encuentro el archivo destino en el repo: {NOMBRE_ARCHIVO_DESTINO}")
else:
    print(f"🔴 ERROR: No encuentro el archivo origen: {NOMBRE_ARCHIVO_ORIGEN}")
# Out:
# 🔄 Iniciando trasplante...
#    💊 Fuente (Nuevo): Opus_Phase_1_EDA_Interacciones_Parada_Optima_vPaper.ipynb
#    💉 Destino (Repo): Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#
# ✅ ÉXITO: El archivo en el repo 'Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb' ahora tiene el contenido de la V2.
#    -> Git detectará esto como una 'Modificación' del archivo original.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "se reemplazo nueva version de libreta de parada optima desde forked_files fuera del repo" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev c9881c3] se reemplazo nueva version de libreta de parada optima desde forked_files fuera del repo
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb (90%)
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 460.73 KiB | 7.55 MiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    e4db07e..c9881c3  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
import json
import glob
import os

# ==============================================================================
# CONFIGURACIÓN DE RUTA: TU REPOSITORIO
# ==============================================================================
REPO_ROOT = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza"

def sanitize_notebooks(directory_path):
    print(f"🕵️‍♂️ Escaneando sector: {directory_path} en busca de widgets tóxicos...")

    # Buscar todos los archivos .ipynb (recursivamente en carpetas)
    files = glob.glob(f"{directory_path}/**/*.ipynb", recursive=True)

    cleaned_count = 0

    for file_path in files:
        try:
            # 1. Cargar el JSON del notebook
            with open(file_path, 'r', encoding='utf-8') as f:
                nb = json.load(f)

            # 2. DETECTAR INFECCIÓN: ¿Tiene metadatos de widgets?
            is_infected = 'widgets' in nb.get('metadata', {})

            # 3. CIRUGÍA: Extirpar la sección 'widgets'
            if is_infected:
                del nb['metadata']['widgets']

                # Guardar el paciente curado
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(nb, f, indent=1)

                print(f"   💊 DESINFECTADO: {os.path.basename(file_path)}")
                cleaned_count += 1

        except Exception as e:
            print(f"   ⚠️ Error leyendo {os.path.basename(file_path)}: {e}")

    if cleaned_count == 0:
        print("✅ TODO LIMPIO. Ningún archivo requirió cirugía.")
    else:
        print(f"✅ OPERACIÓN COMPLETADA: {cleaned_count} archivos limpiados.")
        print("   -> Ahora es seguro hacer Commit y Push. GitHub mostrará el historial.")

# EJECUCIÓN INMEDIATA
sanitize_notebooks(REPO_ROOT)
# Out:
# 🕵️‍♂️ Escaneando sector: /content/drive/MyDrive/_Pienza/Github_Repository/pienza en busca de widgets tóxicos...
# ✅ TODO LIMPIO. Ningún archivo requirió cirugía.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "se puso placeholder en nb parada optima para probar si funciona el widget detox" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_2_Data_Engineering/Opus_Phase_1_Geospatial_Reconciliation_Part_1.ipynb
# M	Notebooks/Phase_2_Data_Engineering/opus_phase_1_geospatial_reconciliation_part_3_production.ipynb
# M	Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
# M	Notebooks/Phase_4_Unsupervised_ML/Copy of Opus_Phase_2_ML_Clustering_GeoEspacial_Polygons.ipynb
# M	Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN.ipynb
# M	Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN_V2.ipynb
# M	Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb
# M	Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_2_Data_Engineering/Opus_Phase_1_Geospatial_Reconciliation_Part_1.ipynb
#  M Notebooks/Phase_2_Data_Engineering/opus_phase_1_geospatial_reconciliation_part_3_production.ipynb
#  M Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#  M "Notebooks/Phase_4_Unsupervised_ML/Copy of Opus_Phase_2_ML_Clustering_GeoEspacial_Polygons.ipynb"
#  M Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN.ipynb
#  M Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN_V2.ipynb
#  M Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb
#  M Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev ca7534e] se puso placeholder en nb parada optima para probar si funciona el widget detox
#  9 files changed, 31974 insertions(+), 9 deletions(-)
#  rewrite Notebooks/Phase_2_Data_Engineering/Opus_Phase_1_Geospatial_Reconciliation_Part_1.ipynb (97%)
#  rewrite Notebooks/Phase_2_Data_Engineering/opus_phase_1_geospatial_reconciliation_part_3_production.ipynb (99%)
#  rewrite Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb (90%)
#  rewrite Notebooks/Phase_4_Unsupervised_ML/Copy of Opus_Phase_2_ML_Clustering_GeoEspacial_Polygons.ipynb (87%)
#  rewrite Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN.ipynb (80%)
#  rewrite Notebooks/Phase_4_Unsupervised_ML/Opus_Phase_2_ML_Clustering_GeoEspacial_HDBSCAN_V2.ipynb (76%)
#  rewrite Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb (89%)
#  rewrite Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb (86%)
# Enumerating objects: 31, done.
# Counting objects: 100% (31/31), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 125.03 KiB | 431.00 KiB/s, done.
# Total 16 (delta 14), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (14/14), completed with 14 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    c9881c3..ca7534e  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "el detox de widgets funcionó, se quitó el placeholder de nb parada optima, todo vobo" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 8f7b1db] el detox de widgets funcionó, se quitó el placeholder de nb parada optima, todo vobo
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb (90%)
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1.25 KiB | 183.00 KiB/s, done.
# Total 6 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    ca7534e..8f7b1db  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
import json
import glob
import os

# ==============================================================================
# CONFIGURACIÓN DE RUTA: TU REPOSITORIO
# ==============================================================================
REPO_ROOT = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza"

def sanitize_notebooks(directory_path):
    print(f"🕵️‍♂️ Escaneando sector: {directory_path} en busca de widgets tóxicos...")

    # Buscar todos los archivos .ipynb (recursivamente en carpetas)
    files = glob.glob(f"{directory_path}/**/*.ipynb", recursive=True)

    cleaned_count = 0

    for file_path in files:
        try:
            # 1. Cargar el JSON del notebook
            with open(file_path, 'r', encoding='utf-8') as f:
                nb = json.load(f)

            # 2. DETECTAR INFECCIÓN: ¿Tiene metadatos de widgets?
            is_infected = 'widgets' in nb.get('metadata', {})

            # 3. CIRUGÍA: Extirpar la sección 'widgets'
            if is_infected:
                del nb['metadata']['widgets']

                # Guardar el paciente curado
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(nb, f, indent=1)

                print(f"   💊 DESINFECTADO: {os.path.basename(file_path)}")
                cleaned_count += 1

        except Exception as e:
            print(f"   ⚠️ Error leyendo {os.path.basename(file_path)}: {e}")

    if cleaned_count == 0:
        print("✅ TODO LIMPIO. Ningún archivo requirió cirugía.")
    else:
        print(f"✅ OPERACIÓN COMPLETADA: {cleaned_count} archivos limpiados.")
        print("   -> Ahora es seguro hacer Commit y Push. GitHub mostrará el historial.")

# EJECUCIÓN INMEDIATA
sanitize_notebooks(REPO_ROOT)
# Out:
# 🕵️‍♂️ Escaneando sector: /content/drive/MyDrive/_Pienza/Github_Repository/pienza en busca de widgets tóxicos...
# ✅ TODO LIMPIO. Ningún archivo requirió cirugía.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "primer commit nb EDA Pienza Paper, violin plot Traffic Index segmentada por bins de EPH" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
# Refresh index: 100% (88/88), done.
#  M Notebooks/Pienza_Git_Control.ipynb
# ?? Notebooks/Phase_3_EDA/Pienza_Phase_3_EDA_paper.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev dbbca85] primer commit nb EDA Pienza Paper, violin plot Traffic Index segmentada por bins de EPH
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 100644 Notebooks/Phase_3_EDA/Pienza_Phase_3_EDA_paper.ipynb
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 604.59 KiB | 3.25 MiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    8f7b1db..dbbca85  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "refactorizó nb parada optima matriz playbook ahora tiene probabilidades; en nb EDA paper se agregó probability funnel y market quadrants" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# M	Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
# M	Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_univariado.ipynb
# M	Notebooks/Phase_3_EDA/Pienza_Phase_3_EDA_paper.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
#  M Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb
#  M Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_univariado.ipynb
#  M Notebooks/Phase_3_EDA/Pienza_Phase_3_EDA_paper.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev 12496eb] refactorizó nb parada optima matriz playbook ahora tiene probabilidades; en nb EDA paper se agregó probability funnel y market quadrants
#  4 files changed, 4 insertions(+), 4 deletions(-)
#  rewrite Notebooks/Phase_3_EDA/Opus_Phase_1_EDA_Interacciones_Parada_Optima.ipynb (88%)
#  rewrite Notebooks/Phase_3_EDA/Pienza_Phase_3_EDA_paper.ipynb (73%)
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.67 MiB | 2.52 MiB/s, done.
# Total 8 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    dbbca85..12496eb  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %% [markdown]
# # Celda para Bajar TEX a /Scientific

# %%
# ==============================================================================
# OPERACIÓN: TIERRA QUEMADA (BORRAR TODO -> DESCARGAR FRESCO)
# ==============================================================================
import os
import shutil
import urllib.parse
import subprocess
from google.colab import userdata

# 1. SEGURIDAD DE ENTORNO
# Nos movemos a la raíz para no estar parados sobre la carpeta que vamos a explotar
os.chdir("/content")

# 2. CONFIGURACIÓN
RUTA_DESTINO = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza/The_Pienza_Papers/Pienza_Papers_Scientific"

print("🔥 INICIANDO PROTOCOLO DE TIERRA QUEMADA...")

# 3. AUTENTICACIÓN
try:
    raw_token = userdata.get('ov_pass')
    raw_url = userdata.get('ov_url_base')
    clean_base = raw_url.replace("https://", "").replace("http://", "").strip("/")
    safe_token = urllib.parse.quote(raw_token, safe='')
    GIT_URL_FINAL = f"https://git:{safe_token}@{clean_base}"
except Exception as e:
    print(f"🔴 ERROR CREDENCIALES: {e}")
    raise

# 4. ELIMINACIÓN TOTAL (SCORCHED EARTH)
if os.path.exists(RUTA_DESTINO):
    print(f"🗑️ Eliminando carpeta existente: {os.path.basename(RUTA_DESTINO)}...")
    shutil.rmtree(RUTA_DESTINO) # Adiós. Se borró todo.
else:
    print("⚠️ La carpeta no existía. Creando desde cero...")

# 5. DESCARGA DIRECTA (CLONADO)
print("📡 Descargando copia fresca desde Overleaf...")

try:
    # Al no existir la carpeta (porque la borramos), Git clone la crea y descarga ahí directo.
    subprocess.run(["git", "clone", GIT_URL_FINAL, RUTA_DESTINO], check=True, capture_output=True)
    print("✅ Descarga completada.")
except subprocess.CalledProcessError as e:
    print(f"💥 ERROR CRÍTICO: Falló la descarga.\n{e.stderr.decode('utf-8')}")
    print("☠️ ALERTA: Tu carpeta local ha sido eliminada y la descarga falló. Restaura desde Overleaf si es necesario.")
    raise Exception("Misión Fallida.")

# 6. LIMPIEZA TÁCTICA (ELIMINAR RASTROS DE GIT)
# Esto es vital. Borramos la carpeta .git que vino de Overleaf para que no choque con tu Repo Pienza.
git_folder_overleaf = os.path.join(RUTA_DESTINO, ".git")
if os.path.exists(git_folder_overleaf):
    shutil.rmtree(git_folder_overleaf)
    print("🧹 Carpeta .git de Overleaf eliminada (Integración limpia asegurada).")

print("\n🏆 OPERACIÓN FINALIZADA.")
print("   Tienes una copia 100% fresca de Overleaf en tu Drive.")
print("👉 EJECUTA TU 'GIT COMMIT' UNIVERSAL AHORA.")
# Out:
# 🔥 INICIANDO PROTOCOLO DE TIERRA QUEMADA...
# 🗑️ Eliminando carpeta existente: Pienza_Papers_Scientific...
# 📡 Descargando copia fresca desde Overleaf...
# ✅ Descarga completada.
# 🧹 Carpeta .git de Overleaf eliminada (Integración limpia asegurada).
#
# 🏆 OPERACIÓN FINALIZADA.
#    Tienes una copia 100% fresca de Overleaf en tu Drive.
# 👉 EJECUTA TU 'GIT COMMIT' UNIVERSAL AHORA.

# %% [markdown]
# # CELDA PARA MATAR TOXICIDAD DE WIDGETS (ANTES DE CADA COMMIT):

# %%
import json
import glob
import os

# ==============================================================================
# CONFIGURACIÓN DE RUTA: TU REPOSITORIO
# ==============================================================================
REPO_ROOT = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza"

def sanitize_notebooks(directory_path):
    print(f"🕵️‍♂️ Escaneando sector: {directory_path} en busca de widgets tóxicos...")

    # Buscar todos los archivos .ipynb (recursivamente en carpetas)
    files = glob.glob(f"{directory_path}/**/*.ipynb", recursive=True)

    cleaned_count = 0

    for file_path in files:
        try:
            # 1. Cargar el JSON del notebook
            with open(file_path, 'r', encoding='utf-8') as f:
                nb = json.load(f)

            # 2. DETECTAR INFECCIÓN: ¿Tiene metadatos de widgets?
            is_infected = 'widgets' in nb.get('metadata', {})

            # 3. CIRUGÍA: Extirpar la sección 'widgets'
            if is_infected:
                del nb['metadata']['widgets']

                # Guardar el paciente curado
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(nb, f, indent=1)

                print(f"   💊 DESINFECTADO: {os.path.basename(file_path)}")
                cleaned_count += 1

        except Exception as e:
            print(f"   ⚠️ Error leyendo {os.path.basename(file_path)}: {e}")

    if cleaned_count == 0:
        print("✅ TODO LIMPIO. Ningún archivo requirió cirugía.")
    else:
        print(f"✅ OPERACIÓN COMPLETADA: {cleaned_count} archivos limpiados.")
        print("   -> Ahora es seguro hacer Commit y Push. GitHub mostrará el historial.")

# EJECUCIÓN INMEDIATA
sanitize_notebooks(REPO_ROOT)
# Out:
# 🕵️‍♂️ Escaneando sector: /content/drive/MyDrive/_Pienza/Github_Repository/pienza en busca de widgets tóxicos...
# ✅ TODO LIMPIO. Ningún archivo requirió cirugía.

# %% [markdown]
# # CELDA PARA HACER COMMITS (EJECTUAR CADA VEZ):

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Workaround para Git Latex; paper: probabil" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")

# %% [markdown]
# # extra stuff

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
 # ==============================================================================
# ULTIMATE SEARCH: LOCATING "Master_Clustering_Features"
# ==============================================================================
import os

# Buscamos en toda la raíz del proyecto para no fallar
ROOT_PIENZA = "/content/drive/MyDrive/"

if os.path.exists(ROOT_PIENZA):
    print(f"📡 Iniciando escaneo profundo en: {ROOT_PIENZA}...")
    # Buscamos el término exacto dentro de los archivos .ipynb
    # Agregamos '2>/dev/null' para ignorar errores de permisos de carpetas de sistema
    # !grep -rli "Master_Clustering_Features" "{ROOT_PIENZA}" 2>/dev/null
    print("\n✅ Búsqueda finalizada.")
else:
    print(f"🔴 ERROR: No se encuentra la ruta {ROOT_PIENZA}. Verifica el nombre de la carpeta en tu Drive.")
# Out:
# 📡 Iniciando escaneo profundo en: /content/drive/MyDrive/...
# /content/drive/MyDrive/Colab Notebooks/Opus_Phase_0_ETL_v7.ipynb
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Pienza, Chairman of the Board -> Technician
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Supervisor - Dolly ETL Technician
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Paste January 25, 2026 - 9:45PM
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Paste January 28, 2026 - 9:57AM
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Bof Sovereign Node: GANtastic! #allthingsGit LIVE from Anzures!
# ^C
#
# ✅ Búsqueda finalizada.

# %%
 # ==============================================================================
# ULTIMATE SEARCH: LOCATING "Master_Clustering_Features"
# ==============================================================================
import os

# Buscamos en toda la raíz del proyecto para no fallar
ROOT_PIENZA = "/content/drive/MyDrive/"

if os.path.exists(ROOT_PIENZA):
    print(f"📡 Iniciando escaneo profundo en: {ROOT_PIENZA}...")
    # Buscamos el término exacto dentro de los archivos .ipynb
    # Agregamos '2>/dev/null' para ignorar errores de permisos de carpetas de sistema
    # !grep -rli "master_clustering_features.csv" "{ROOT_PIENZA}" 2>/dev/null
    print("\n✅ Búsqueda finalizada.")
else:
    print(f"🔴 ERROR: No se encuentra la ruta {ROOT_PIENZA}. Verifica el nombre de la carpeta en tu Drive.")
# Out:
# 📡 Iniciando escaneo profundo en: /content/drive/MyDrive/...
# /content/drive/MyDrive/Colab Notebooks/Pienza_Git_Control.ipynb
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Pienza, Chairman of the Board -> Technician
# ^C
#
# ✅ Búsqueda finalizada.

# %% [markdown]
# # PASO 3: EL SALTO SOBERANO (Fusión de dev a main)
# SOLO corre esta celda cuando algo esté 100% terminado y quieras que el mundo lo vea en tu página principal de GitHub.
