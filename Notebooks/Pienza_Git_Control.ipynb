# %%
# ==============================================================================
# CELDA 1: PIENZA COMMAND CENTER - BOOTSTRAP (SECURE VERSION)
# ==============================================================================
# Status: Hardened. Logic decoupled from credentials.
# ==============================================================================
from google.colab import drive, userdata # <--- Inyectamos el gestor de secretos
import os

# 1. Montar Bóveda de Google Drive
print("📂 Sincronizando con Google Drive...")
drive.mount('/content/drive')

# 2. Configuración de Credenciales SOBERANAS
GITHUB_USER = "WiseExMachina"

# Recuperamos la llave desde el búnker de 'Secrets' (Icono de llave 🔑 a la izquierda)
try:
    GITHUB_TOKEN = userdata.get('Git_Secret') # <--- Nombre de tu Secret
    print("✅ Llave Maestra (Secret) recuperada del búnker.")
except userdata.SecretNotFoundError:
    print("🔴 ERROR: No se encontró el Secret llamado 'Github'.")
    print("   Asegúrate de que el nombre sea exacto y que hayas dado permiso al notebook.")
    raise

REPO_NAME = "pienza"

# 3. DEFINICIÓN DE RUTA MAESTRA (GITHUB REPOSITORY)
REPO_PATH = f"/content/drive/MyDrive/_Pienza/Github_Repository/{REPO_NAME}"
REPO_URL = f"https://{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"

# 4. Configuración de Identidad Git
# !git config --global user.email "bernardolw@gmail.com"
# !git config --global user.name "{GITHUB_USER}"

print(f"\n✅ INFRAESTRUCTURA LISTA Y SEGURA.")
print(f"📍 Coordenada del Repo: {REPO_PATH}")
# Out:
# 📂 Sincronizando con Google Drive...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Llave Maestra (Secret) recuperada del búnker.
#
# ✅ INFRAESTRUCTURA LISTA Y SEGURA.
# 📍 Coordenada del Repo: /content/drive/MyDrive/_Pienza/Github_Repository/pienza

# %%
# ==============================================================================
# CELDA 2: CLONAR O SINCRONIZAR
# ==============================================================================
if not os.path.exists(REPO_PATH):
    print(f"🚀 No se detectó repo local. Clonando {REPO_NAME} en la Bóveda...")
    os.makedirs(os.path.dirname(REPO_PATH), exist_ok=True)
    # !git clone {REPO_URL} "{REPO_PATH}"
else:
    print(f"🔄 Repositorio detectado. Sincronizando (PULL) desde GitHub...")
    # %cd "{REPO_PATH}"
    # !git pull origin main

print("\n✅ ESTADO: SINCRONIZADO CON LA NUBE.")
# Out:
# 🔄 Repositorio detectado. Sincronizando (PULL) desde GitHub...
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# From https://github.com/WiseExMachina/pienza
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# ✅ ESTADO: SINCRONIZADO CON LA NUBE.

# %% [markdown]
# # Celda para Bajar TEX a /Scientific

# %%
# ==============================================================================
# OPERACIÓN: TIERRA QUEMADA (BORRAR TODO -> DESCARGAR FRESCO)
# ==============================================================================
import os
import shutil
import urllib.parse
import subprocess
from google.colab import userdata

# 1. SEGURIDAD DE ENTORNO
# Nos movemos a la raíz para no estar parados sobre la carpeta que vamos a explotar
os.chdir("/content")

# 2. CONFIGURACIÓN
RUTA_DESTINO = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza/The_Pienza_Papers/Pienza_Papers_Scientific"

print("🔥 INICIANDO PROTOCOLO DE TIERRA QUEMADA...")

# 3. AUTENTICACIÓN
try:
    raw_token = userdata.get('ov_pass')
    raw_url = userdata.get('ov_url_base')
    clean_base = raw_url.replace("https://", "").replace("http://", "").strip("/")
    safe_token = urllib.parse.quote(raw_token, safe='')
    GIT_URL_FINAL = f"https://git:{safe_token}@{clean_base}"
except Exception as e:
    print(f"🔴 ERROR CREDENCIALES: {e}")
    raise

# 4. ELIMINACIÓN TOTAL (SCORCHED EARTH)
if os.path.exists(RUTA_DESTINO):
    print(f"🗑️ Eliminando carpeta existente: {os.path.basename(RUTA_DESTINO)}...")
    shutil.rmtree(RUTA_DESTINO) # Adiós. Se borró todo.
else:
    print("⚠️ La carpeta no existía. Creando desde cero...")

# 5. DESCARGA DIRECTA (CLONADO)
print("📡 Descargando copia fresca desde Overleaf...")

try:
    # Al no existir la carpeta (porque la borramos), Git clone la crea y descarga ahí directo.
    subprocess.run(["git", "clone", GIT_URL_FINAL, RUTA_DESTINO], check=True, capture_output=True)
    print("✅ Descarga completada.")
except subprocess.CalledProcessError as e:
    print(f"💥 ERROR CRÍTICO: Falló la descarga.\n{e.stderr.decode('utf-8')}")
    print("☠️ ALERTA: Tu carpeta local ha sido eliminada y la descarga falló. Restaura desde Overleaf si es necesario.")
    raise Exception("Misión Fallida.")

# 6. LIMPIEZA TÁCTICA (ELIMINAR RASTROS DE GIT)
# Esto es vital. Borramos la carpeta .git que vino de Overleaf para que no choque con tu Repo Pienza.
git_folder_overleaf = os.path.join(RUTA_DESTINO, ".git")
if os.path.exists(git_folder_overleaf):
    shutil.rmtree(git_folder_overleaf)
    print("🧹 Carpeta .git de Overleaf eliminada (Integración limpia asegurada).")

print("\n🏆 OPERACIÓN FINALIZADA.")
print("   Tienes una copia 100% fresca de Overleaf en tu Drive.")
print("👉 EJECUTA TU 'GIT COMMIT' UNIVERSAL AHORA.")
# Out:
# 🔥 INICIANDO PROTOCOLO DE TIERRA QUEMADA...
# 🗑️ Eliminando carpeta existente: Pienza_Papers_Scientific...
# 📡 Descargando copia fresca desde Overleaf...
# ✅ Descarga completada.
# 🧹 Carpeta .git de Overleaf eliminada (Integración limpia asegurada).
#
# 🏆 OPERACIÓN FINALIZADA.
#    Tienes una copia 100% fresca de Overleaf en tu Drive.
# 👉 EJECUTA TU 'GIT COMMIT' UNIVERSAL AHORA.

# %% [markdown]
# # CELDA PARA MATAR TOXICIDAD DE WIDGETS (ANTES DE CADA COMMIT):

# %%
import json
import glob
import os

# ==============================================================================
# CONFIGURACIÓN DE RUTA: TU REPOSITORIO
# ==============================================================================
REPO_ROOT = "/content/drive/MyDrive/_Pienza/Github_Repository/pienza"

def sanitize_notebooks(directory_path):
    print(f"🕵️‍♂️ Escaneando sector: {directory_path} en busca de widgets tóxicos...")

    # Buscar todos los archivos .ipynb (recursivamente en carpetas)
    files = glob.glob(f"{directory_path}/**/*.ipynb", recursive=True)

    cleaned_count = 0

    for file_path in files:
        try:
            # 1. Cargar el JSON del notebook
            with open(file_path, 'r', encoding='utf-8') as f:
                nb = json.load(f)

            # 2. DETECTAR INFECCIÓN: ¿Tiene metadatos de widgets?
            is_infected = 'widgets' in nb.get('metadata', {})

            # 3. CIRUGÍA: Extirpar la sección 'widgets'
            if is_infected:
                del nb['metadata']['widgets']

                # Guardar el paciente curado
                with open(file_path, 'w', encoding='utf-8') as f:
                    json.dump(nb, f, indent=1)

                print(f"   💊 DESINFECTADO: {os.path.basename(file_path)}")
                cleaned_count += 1

        except Exception as e:
            print(f"   ⚠️ Error leyendo {os.path.basename(file_path)}: {e}")

    if cleaned_count == 0:
        print("✅ TODO LIMPIO. Ningún archivo requirió cirugía.")
    else:
        print(f"✅ OPERACIÓN COMPLETADA: {cleaned_count} archivos limpiados.")
        print("   -> Ahora es seguro hacer Commit y Push. GitHub mostrará el historial.")

# EJECUCIÓN INMEDIATA
sanitize_notebooks(REPO_ROOT)
# Out:
# 🕵️‍♂️ Escaneando sector: /content/drive/MyDrive/_Pienza/Github_Repository/pienza en busca de widgets tóxicos...

# %% [markdown]
# # CELDA PARA HACER COMMITS (EJECTUAR CADA VEZ):

# %%
# ==============================================================================
# PIENZA SYSTEM CONSOLE: MASTER SYNC (DEV AXIS)
# ==============================================================================
msg = "Se
" # <--- CAMBIA ESTO

import os
# %cd "{REPO_PATH}"

# Aseguramos que estamos en el taller
# !git checkout dev

print("🔍 Verificando estado del búnker...")
# !git status -s

print("\n📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...")
# !git add .

# Evitar commits vacíos
status = os.popen('git status --porcelain').read()
if not status:
    print("✨ NADA QUE CAMBIAR. El sistema está al día.")
else:
    # !git commit -m "{msg}"
    # !git push origin dev
    print("\n🏆 PROGRESO INMORTALIZADO EN DEV.")
# Out:
# /content/drive/MyDrive/_Pienza/Github_Repository/pienza
# D	Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N16_XGB_multiclase_monolito.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N17_XGB_multiclase_cascada.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Copy of opus_1_phase_3_home_vector_alignment_score_v2.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N10_Arbol_multiclase.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N12_XGB_multiclase(deprecar).ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N13_XGB_multiclase.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N14_LogReg_multiclase_srtratk.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw(deprecar).ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N16_XGB_multiclase_monolito_deprecar.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N17_XGB_multiclase_cascada_deprecar.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N1_PCA_V2_sin_meter_mano.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N2_PCA_V2_metiendo_mano.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N3_PCA_V2_metiendo_mano_con_KM.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N4_Bayesiano_Ingenuo.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N5_NB_numcat_multiclase.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N6_NB_numcat_binario.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N7_LogReg_multiclase.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Opus_P3_N9_DCC_multiclase_deprecar.ipynb
# D	Notebooks/Phase_5_Supervised_ML/Pienza_P5_paper.ipynb
# D	Notebooks/Phase_6_GAN_Simulations/00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb
# M	Notebooks/Pienza_Git_Control.ipynb
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# 🔍 Verificando estado del búnker...
# Refresh index: 100% (136/136), done.
#  D "Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N16_XGB_multiclase_monolito.ipynb"
#  D "Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N17_XGB_multiclase_cascada.ipynb"
#  D "Notebooks/Phase_5_Supervised_ML/Copy of opus_1_phase_3_home_vector_alignment_score_v2.ipynb"
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N10_Arbol_multiclase.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N11_SVM_binario.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N12_XGB_multiclase(deprecar).ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N13_XGB_multiclase.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N14_LogReg_multiclase_srtratk.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw(deprecar).ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N15_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N16_XGB_multiclase_monolito_deprecar.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N17_XGB_multiclase_cascada_deprecar.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N1_PCA_V2_sin_meter_mano.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N2_PCA_V2_metiendo_mano.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N3_PCA_V2_metiendo_mano_con_KM.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N4_Bayesiano_Ingenuo.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N5_NB_numcat_multiclase.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N6_NB_numcat_binario.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N7_LogReg_multiclase.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N8_LogReg_binario.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Opus_P3_N9_DCC_multiclase_deprecar.ipynb
#  D Notebooks/Phase_5_Supervised_ML/Pienza_P5_paper.ipynb
#  D Notebooks/Phase_6_GAN_Simulations/00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb
#  M Notebooks/Pienza_Git_Control.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0500_Pienza_Home_Vector_V2.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0501_Pienza_PCA_V2_sin_meter_mano.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0502_Pienza_PCA_V2_metiendo_mano.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0503_Pienza_PCA_V2_metiendo_mano_con_KM.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0504_Pienza_Bayesiano_Ingenuo.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0505_Pienza_NB_numcat_multiclase.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0506_Pienza_NB_numcat_binario.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0507_Pienza_LogReg_multiclase.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0508_Pienza_LogReg_binario.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0509_Pienza_DCC_multiclase_deprecar.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0510_Pienza_Arbol_multiclase.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0511_Pienza_SVM_binario.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0512_Pienza_XGB_multiclase(deprecar).ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0513_Pienza_XGB_multiclase(deprecar).ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0514_Pienza_LogReg_multiclase_srtratk.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0515_Pienza_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0516_Pienza_XGB_multiclase_raw(deprecar).ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0517_Pienza_XGB_multiclase_monolito.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0518_Pienza_XGB_multiclase_cascada.ipynb
# ?? Notebooks/Phase_5_Supervised_ML/0519_Pienza_paper.ipynb
#
# 📡 Sincronizando con la Bóveda de GitHub (Eje DEV)...
# [dev fd10a76] Se droppearon libretas deprecadas; renombraron todas las libretas de fase 5.
#  26 files changed, 3 insertions(+), 5 deletions(-)
#  rename Notebooks/{Phase_6_GAN_Simulations => Phase_5_Supervised_ML}/00_Pienza_Phase_6_Transformer_T2Z_Classifier.ipynb (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Copy of opus_1_phase_3_home_vector_alignment_score_v2.ipynb => 0500_Pienza_Home_Vector_V2.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N1_PCA_V2_sin_meter_mano.ipynb => 0501_Pienza_PCA_V2_sin_meter_mano.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N2_PCA_V2_metiendo_mano.ipynb => 0502_Pienza_PCA_V2_metiendo_mano.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N3_PCA_V2_metiendo_mano_con_KM.ipynb => 0503_Pienza_PCA_V2_metiendo_mano_con_KM.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N4_Bayesiano_Ingenuo.ipynb => 0504_Pienza_Bayesiano_Ingenuo.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N5_NB_numcat_multiclase.ipynb => 0505_Pienza_NB_numcat_multiclase.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N6_NB_numcat_binario.ipynb => 0506_Pienza_NB_numcat_binario.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N7_LogReg_multiclase.ipynb => 0507_Pienza_LogReg_multiclase.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N8_LogReg_binario.ipynb => 0508_Pienza_LogReg_binario.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N9_DCC_multiclase_deprecar.ipynb => 0509_Pienza_DCC_multiclase_deprecar.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N10_Arbol_multiclase.ipynb => 0510_Pienza_Arbol_multiclase.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N11_SVM_binario.ipynb => 0511_Pienza_SVM_binario.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N12_XGB_multiclase(deprecar).ipynb => 0512_Pienza_XGB_multiclase(deprecar).ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N13_XGB_multiclase.ipynb => 0513_Pienza_XGB_multiclase(deprecar).ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N14_LogReg_multiclase_srtratk.ipynb => 0514_Pienza_LogReg_multiclase_srtratk.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N15_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb => 0515_Pienza_XGB_multiclase_raw_split1-4vs5-6_strat.ipynb} (100%)
#  rename Notebooks/Phase_5_Supervised_ML/{Opus_P3_N15_XGB_multiclase_raw(deprecar).ipynb => 0516_Pienza_XGB_multiclase_raw(deprecar).ipynb} (100%)
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/0517_Pienza_XGB_multiclase_monolito.ipynb
#  create mode 100644 Notebooks/Phase_5_Supervised_ML/0518_Pienza_XGB_multiclase_cascada.ipynb
#  rename Notebooks/Phase_5_Supervised_ML/{Pienza_P5_paper.ipynb => 0519_Pienza_paper.ipynb} (100%)
#  delete mode 100644 Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N16_XGB_multiclase_monolito.ipynb
#  delete mode 100644 Notebooks/Phase_5_Supervised_ML/Copy of Opus_P3_N17_XGB_multiclase_cascada.ipynb
#  delete mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N16_XGB_multiclase_monolito_deprecar.ipynb
#  delete mode 100644 Notebooks/Phase_5_Supervised_ML/Opus_P3_N17_XGB_multiclase_cascada_deprecar.ipynb
#  rewrite Notebooks/Pienza_Git_Control.ipynb (64%)
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 4.87 MiB | 4.11 MiB/s, done.
# Total 8 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 5 local objects.
# To https://github.com/WiseExMachina/pienza.git
#    b0c2919..fd10a76  dev -> dev
#
# 🏆 PROGRESO INMORTALIZADO EN DEV.

# %% [markdown]
# # extra stuff

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
 # ==============================================================================
# ULTIMATE SEARCH: LOCATING "Master_Clustering_Features"
# ==============================================================================
import os

# Buscamos en toda la raíz del proyecto para no fallar
ROOT_PIENZA = "/content/drive/MyDrive/"

if os.path.exists(ROOT_PIENZA):
    print(f"📡 Iniciando escaneo profundo en: {ROOT_PIENZA}...")
    # Buscamos el término exacto dentro de los archivos .ipynb
    # Agregamos '2>/dev/null' para ignorar errores de permisos de carpetas de sistema
    # !grep -rli "Master_Clustering_Features" "{ROOT_PIENZA}" 2>/dev/null
    print("\n✅ Búsqueda finalizada.")
else:
    print(f"🔴 ERROR: No se encuentra la ruta {ROOT_PIENZA}. Verifica el nombre de la carpeta en tu Drive.")
# Out:
# 📡 Iniciando escaneo profundo en: /content/drive/MyDrive/...
# /content/drive/MyDrive/Colab Notebooks/Opus_Phase_0_ETL_v7.ipynb
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Pienza, Chairman of the Board -> Technician
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Supervisor - Dolly ETL Technician
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Paste January 25, 2026 - 9:45PM
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Paste January 28, 2026 - 9:57AM
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Bof Sovereign Node: GANtastic! #allthingsGit LIVE from Anzures!
# ^C
#
# ✅ Búsqueda finalizada.

# %%
 # ==============================================================================
# ULTIMATE SEARCH: LOCATING "Master_Clustering_Features"
# ==============================================================================
import os

# Buscamos en toda la raíz del proyecto para no fallar
ROOT_PIENZA = "/content/drive/MyDrive/"

if os.path.exists(ROOT_PIENZA):
    print(f"📡 Iniciando escaneo profundo en: {ROOT_PIENZA}...")
    # Buscamos el término exacto dentro de los archivos .ipynb
    # Agregamos '2>/dev/null' para ignorar errores de permisos de carpetas de sistema
    # !grep -rli "master_clustering_features.csv" "{ROOT_PIENZA}" 2>/dev/null
    print("\n✅ Búsqueda finalizada.")
else:
    print(f"🔴 ERROR: No se encuentra la ruta {ROOT_PIENZA}. Verifica el nombre de la carpeta en tu Drive.")
# Out:
# 📡 Iniciando escaneo profundo en: /content/drive/MyDrive/...
# /content/drive/MyDrive/Colab Notebooks/Pienza_Git_Control.ipynb
# /content/drive/MyDrive/Data Science Uncategorized/Google AI Studio/Branch of Pienza, Chairman of the Board -> Technician
# ^C
#
# ✅ Búsqueda finalizada.

# %% [markdown]
# # PASO 3: EL SALTO SOBERANO (Fusión de dev a main)
# SOLO corre esta celda cuando algo esté 100% terminado y quieras que el mundo lo vea en tu página principal de GitHub.
